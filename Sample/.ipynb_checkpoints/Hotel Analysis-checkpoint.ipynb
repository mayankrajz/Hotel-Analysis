# %% [markdown]
# **<h1>Hotel Analysis Summary</h1>**

# %% [markdown]
# In this analysis, I began with an uneven and unstructured dataset containing various details about hotels. The data required significant preprocessing and transformation to make it suitable for analysis. I utilized PySpark, a powerful tool for handling large datasets, to efficiently manage and transform the data.

# %% [markdown]
# **<h3>Data Loading and Transformation</h3>**
#
# **Loading Data:** The raw dataset, which had inconsistencies such as missing values, incorrect data entries, and inconsistent capitalization, was loaded into a PySpark DataFrame. PySpark's distributed computing capabilities allowed for handling this large and uneven dataset effectively.

# %%
pip install pyspark
# Out:
# Requirement already satisfied: pyspark in c:\users\rajma\appdata\local\programs\python\python312\lib\site-packages (3.5.2)
# Requirement already satisfied: py4j==0.10.9.7 in c:\users\rajma\appdata\local\programs\python\python312\lib\site-packages (from pyspark) (0.10.9.7)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pyspark

# %%
from pyspark.sql import SparkSession

# %%
spark= SparkSession.builder.appName('Python').getOrCreate()

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://LAPTOP-DHMNFTDN:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.2</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Python</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
df_pyspark=spark.read.csv('data.csv')

# %%
df_pyspark
# Out:
# DataFrame[_c0: string, _c1: string, _c2: string, _c3: string, _c4: string, _c5: string, _c6: string, _c7: string, _c8: string, _c9: string, _c10: string, _c11: string]

# %%
df_pyspark= spark.read.csv('data.csv',header=True,inferSchema=True)

# %%
df_pyspark
# Out:
# DataFrame[address: string, city: string, state: string, country: string, hotel_star_rating: string, latitude: double, longitude: double, pageurl: string, property_id: int, property_name: string, room_type: string, uniq_id: string]

# %%
type(df_pyspark)
# Out:
# pyspark.sql.dataframe.DataFrame

# %%
df_pyspark.printSchema()
# Out:
# root
#  |-- address: string (nullable = true)
#  |-- city: string (nullable = true)
#  |-- state: string (nullable = true)
#  |-- country: string (nullable = true)
#  |-- hotel_star_rating: string (nullable = true)
#  |-- latitude: double (nullable = true)
#  |-- longitude: double (nullable = true)
#  |-- pageurl: string (nullable = true)
#  |-- property_id: integer (nullable = true)
#  |-- property_name: string (nullable = true)
#  |-- room_type: string (nullable = true)
#  |-- uniq_id: string (nullable = true)

# %%
df_pyspark.columns
# Out:
# ['address',
#  'city',
#  'state',
#  'country',
#  'hotel_star_rating',
#  'latitude',
#  'longitude',
#  'pageurl',
#  'property_id',
#  'property_name',
#  'room_type',
#  'uniq_id']

# %%
df_pyspark.show()
# Out:
# +--------------------+--------------+----------------+-------+-----------------+-----------+-----------+--------------------+-----------+--------------------+--------------------+--------------------+
# |             address|          city|           state|country|hotel_star_rating|   latitude|  longitude|             pageurl|property_id|       property_name|           room_type|             uniq_id|
# +--------------------+--------------+----------------+-------+-----------------+-----------+-----------+--------------------+-----------+--------------------+--------------------+--------------------+
# |KHIRSU. 246147 Pa...|         pauri|     Uttarakhand|  India|             NULL|30.12374875|78.79377365|http://www.bookin...|    1742658|      Khirsu By GMVN| Economy Double Room|a5ea72415f8007fcb...|
# |Kaathadimattam. B...|          ooty|      Tamil Nadu|  India|          3 stars|11.32959492|76.68673217|http://www.bookin...|    1755986| Global Village Ooty|British Empire Ch...|7e0b055417271bbd9...|
# |92 Barog. Distric...|         solan|Himachal Pradesh|  India|             NULL|30.88878834|77.07588672|http://www.bookin...|    1756328| Ellays Dream Resort|Standard Double Room|6c7f385d9d44f9c30...|
# +--------------------+--------------+----------------+-------+-----------------+-----------+-----------+--------------------+-----------+--------------------+--------------------+--------------------+
# only showing top 20 rows

# %% [markdown]
# **<h3>Data Cleaning:</h3>**
#
# **Removing Null Values:** I identified and removed rows with null or missing values to ensure the integrity of the analysis. This step was crucial for avoiding skewed results due to incomplete data.
#
# **Correcting Values:** Erroneous or inconsistent data entries were corrected. For example, incorrect or inconsistent hotel ratings were standardized to a uniform format.
#
# **Letter Correction:** To maintain consistency, the text data was cleaned by capitalizing or formatting strings correctly, ensuring uniformity across columns such as hotel names, locations, and reviews.

# %%
df_pyspark= df_pyspark.na.drop(how='any',subset=['hotel_star_rating'])

# %%
df_pyspark= df_pyspark.na.drop()

# %%
df_pyspark.show()
# Out:
# +--------------------+-----------+----------------+-------+-----------------+-----------+-----------+--------------------+-----------+--------------------+--------------------+--------------------+
# |             address|       city|           state|country|hotel_star_rating|   latitude|  longitude|             pageurl|property_id|       property_name|           room_type|             uniq_id|
# +--------------------+-----------+----------------+-------+-----------------+-----------+-----------+--------------------+-----------+--------------------+--------------------+--------------------+
# |Kaathadimattam. B...|       ooty|      Tamil Nadu|  India|          3 stars|11.32959492|76.68673217|http://www.bookin...|    1755986| Global Village Ooty|British Empire Ch...|7e0b055417271bbd9...|
# |Near White Meadow...|     manāli|Himachal Pradesh|  India|     2-star hotel|32.22145595|77.19583422|http://www.bookin...|    1737428| Hotel Mountain Face|  Budget Double Room|e7482ae06a72dee32...|
# |1 KARIYIL HOUSE K...|  kumarakom|          Kerala|  India|     3-star hotel|9.617156891|76.42783999|http://www.bookin...|    1747391| Swasti house boat 4|         Deluxe Room|b0ac79ef7273575d5...|
# |Opp. Vishal Mega ...|   haridwār|     Uttarakhand|  India|     2-star hotel|29.93724304|78.13998252|http://www.bookin...|    1740370|         Grand Hotel|  Deluxe Double Room|1f64ffd8607a0d8c6...|
# |Coonoor Road. Bes...|       ooty|      Tamil Nadu|  India|     1-star hotel|11.40319815|76.71464927|http://www.bookin...|    1745624|     Hotel Blue Bird|Deluxe Double Roo...|56d39d34f2697247c...|
# |At Post Ganpatipu...|ganpatipule|     Maharashtra|  India|     1-star hotel|17.14958281|73.27330068|http://www.bookin...|    1755130|Center Point Resi...|  Budget Double Room|43a188c462d1156ff...|
# |8433. Arya Nagar....|  new delhi|       Delhi NCR|  India|     3-star hotel|28.64556081|77.21303657|http://www.bookin...|    1743072|        Swisston Inn|  Budget Double Room|39b7cae5995290c5b...|
# |Kasturba Road. Ne...|   mātherān|     Maharashtra|  India|     2-star hotel|18.98533639|73.26979637|http://www.bookin...|    1756188|      Hotel Premdeep|  Deluxe Single Room|e914e1fc861cfaf9f...|
# |Ring Road. Laxmin...|    phaltan|     Maharashtra|  India|     2-star hotel|17.98374349|74.43491925|http://www.bookin...|    1737347|     Hotel Aaryamaan|   Deluxe King Suite|cd5c6f504a77c63c2...|
# |Jaipur Kunda.NH-8...|       jaipur|       Rajasthan|  India|5-star hotel|27.00124923|75.86935043|http://www.bookin...|     493982| lebua Lodge at Amer|         Luxury Tent|293d032fdb717ee57...|
# |New Delhi NCR NH ...|      gurgaon|         Haryana|  India|5-star hotel|28.39220263|76.97651267|http://www.bookin...|     537294|Hyatt Regency Gur...|           Twin Room|c3661e663dae1591f...|
# |Near Circuit Hous...|      jodhpur|       Rajasthan|  India|5-star hotel|26.28247118|73.03818494|http://www.bookin...|     502639|The Ajit Bhawan P...|Executive Double ...|dff8de2c054234de8...|
# |Iblur Gate. Outer...|    bangalore|       Karnataka|  India|5-star hotel|12.91911572|77.66518593|http://www.bookin...|     504682|DoubleTree Suites...|King Bed Studio w...|f56a5b86d864450f0...|
# |New Delhi NCR NH ...|      gurgaon|         Haryana|  India|5-star hotel|28.39220263|76.97651267|http://www.bookin...|     537294|Hyatt Regency Gur...|           King Room|608ba97ebff72d598...|
# +--------------------+-------------+----------------+-------+------------+-----------+-----------+--------------------+-----------+--------------------+--------------------+--------------------+
# only showing top 20 rows

# %% [markdown]
# **Data Conversion:** After cleaning and transforming the data in PySpark, I converted the DataFrame into a Pandas DataFrame. This step enabled more straightforward manipulation and analysis of the data using the extensive libraries available in Python.

# %%
import pandas as pd

# %%
df_pandas = df_pyspark.toPandas()

# %%
df_pandas['city'] = df_pandas['city'].str.capitalize()

# %%
df_pandas
# Out:
#                                                 address       city  \
# 0     Kaathadimattam. Balacola Post. NEAR Siva Tea F...       Ooty
# 1     Near White Meadows Resorts Prini. Manali Distt...     Manāli
# 2     1 KARIYIL HOUSE KUMARAKOM NORTH PO KOTTAYAM. 6...  Kumarakom
# 3     Opp. Vishal Mega Mart. Old Ranipur More. 24940...   Haridwār
# 4     Coonoor Road. Beside Eye Hospital. 643001 Ooty...       Ooty
# ...                                                 ...        ...
# 2462  Zen Enclave. Opp Dispensary Building Near Resi...     Nagpur
# 2463  Opp. City Power House. Jaipur Road. 305001 Ajm...      Ajmer
# 2464  60/1. Vellore-Chittoor Road. Gandhinagar. 6320...    Vellore
# 2465  Zen Enclave. Opp Dispensary Building Near Resi...     Nagpur
# 2466  Plot No.127 Noida-Khoda Road (Opp- Unitech glo...      Noida
#
#                  state country  hotel_rating   latitude  longitude  \
# 0           Tamil Nadu   India  3-star hotel  11.329595  76.686732
# 1     Himachal Pradesh   India  2-star hotel  32.221456  77.195834
# 2               Kerala   India  3-star hotel   9.617157  76.427840
# 3          Uttarakhand   India  2-star hotel  29.937243  78.139983
# 4           Tamil Nadu   India  1-star hotel  11.403198  76.714649
# ...                ...     ...           ...        ...        ...
# 2462       Maharashtra   India  2-star hotel  21.161337  79.078925
# 2463         Rajasthan   India  3-star hotel  26.455199  74.637099
# 2464        Tamil Nadu   India  3-star hotel  12.955515  79.137115
# 2465       Maharashtra   India  2-star hotel  21.161337  79.078925
# 2466     Uttar Pradesh   India  3-star hotel  28.620961  77.354903
#
#                                                 pageurl  property_id  \
# 0     http://www.booking.com/hotel/in/global-village...      1755986
# 1     http://www.booking.com/hotel/in/mountain-face....      1737428
# 2     http://www.booking.com/hotel/in/swasti-house-b...      1747391
# 3     http://www.booking.com/hotel/in/grand-haridwar...      1740370
# 4     http://www.booking.com/hotel/in/blue-bird-ooty...      1745624
# ...                                                 ...          ...
# 2462  http://www.booking.com/hotel/in/orient-inn.en-...      1623145
# 2463  http://www.booking.com/hotel/in/kc-inn.en-gb.h...      1635972
# 2464  http://www.booking.com/hotel/in/rangalaya-roya...      1622298
# 2465  http://www.booking.com/hotel/in/orient-inn.en-...      1623145
# 2466  http://www.booking.com/hotel/in/ascent-biz.en-...      1640594
#
#             property_name                     room_type  \
# 0     Global Village Ooty         British Empire Chalet
# 1     Hotel Mountain Face            Budget Double Room
# 2     Swasti house boat 4                   Deluxe Room
# 3             Grand Hotel            Deluxe Double Room
# 4         Hotel Blue Bird  Deluxe Double Room with Bath
# ...                   ...                           ...
# 2462     Hotel Orient Inn    Deluxe Double or Twin Room
# 2463               Kc Inn            Deluxe Double Room
# 2464      Rangalaya Royal            Standard Twin Room
# 2465     Hotel Orient Inn    Deluxe Double or Twin Room
# 2466     Hotel Ascent Biz            Superior King Room
#
#                                uniq_id
# 0     7e0b055417271bbd9dae902f3e231ed4
# 1     e7482ae06a72dee32708e226d5dcf73d
# 2     b0ac79ef7273575d5ce09de1c8f29db0
# 3     1f64ffd8607a0d8c65394690929220fb
# 4     56d39d34f2697247c00df091dd743c92
# ...                                ...
# 2462  1543cd744e744b68b15bc77fe1657909
# 2463  461cb779f4d3f11708e250d6f86cd6f8
# 2464  c63e340314636491a71f67c8f362a93e
# 2465  ef429e529236ea8883b277c7502c4eb0
# 2466  c79741601a10e02fd46730ea5c17cbb8
#
# [2467 rows x 12 columns]

# %% [markdown]
# **Sorting Data:** The hotel data was then sorted by the hotel_rating column in descending order. This sorting allowed for easy identification of the top-rated hotels, providing valuable insights into the best-performing hotels in the dataset.

# %%
df_pandas= df_pandas.sort_values(by='hotel_rating', ascending=False)

# %%
df_pandas.to_csv('data.csv', index=None)

# %% [markdown]
# **<h3>Data Visualization,</h3>**
# To visualize the cleaned and sorted data, I employed Matplotlib and Seaborn, two popular data visualization libraries in Python:
#
# **Matplotlib:** I used Matplotlib to create basic histogram to visualize the distribution of hotel ratings and the number of hotels under that rating.
#
# **Seaborn:** Seaborn was leveraged for more complex visualizations, such as scatterplot to uncover deeper insights into the dataset. For example, I visualized the relationship between hotel ratings with respect to latitude and longitude across different regions.

# %%
# !pip install matplotlib seaborn --upgrade --quiet

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
plt.figure(figsize=(12, 5))
plt.title("Hotel Rating")
plt.hist(df_pandas.hotel_rating);

# %%
plt.figure(figsize=(12, 5))
plt.title('Hotel Ratings')
sns.scatterplot(x=df_pandas.latitude, 
                y=df_pandas.longitude, 
                hue=df_pandas.hotel_rating,
                s=75);

# %%
plt.figure(figsize=(10, 5))
plt.title('Hotel Ratings')
sns.scatterplot(x=df_pandas.city,
                y=df_pandas.state,
                hue=df_pandas.hotel_rating,
                s=75);

# %%
sns.pairplot(df_pandas, hue='hotel_rating');

# %% [markdown]
# **<h3>Conclusion</h3>**
#
# The process of transforming and analyzing the hotel dataset, from loading it in PySpark to visualizing it using Matplotlib and Seaborn, allowed for a comprehensive understanding of the hotel landscape. The clean and structured data enabled meaningful analysis, and the visualizations provided actionable insights that could be used for decision-making in hotel management and customer satisfaction strategies.
